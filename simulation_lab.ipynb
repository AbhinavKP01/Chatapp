# %% [markdown]
# <a href="https://colab.research.google.com/github/AbhinavKP01/Chatapp/blob/main/simulation_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as p
import numpy as np
Hr=int(input("Enter how many harmonics do u want: "))
l=int(input("Enter length of the box: "))
N=np.linspace(1,Hr, Hr)
for n in N:
  x=np.linspace(0,l, 1000)
  y=((np.sqrt(2/l)*np.sin((n*np.pi*x)/l))+n)
  p.plot(x,y)
# Out:
# Enter how many harmonics do u want: 6
# Enter length of the box: 9

# %% [markdown]
# root(2)/lsin (npix/l)

# %% [markdown]
# motion of a sperical body falling in a viscous medium. Mass of the body is m. It experiances two forces. viscous drag force in upward direction and gravitational force in downward direction.Net force acting on the body F=mg-(6* pi * eta * r * v).
# Acceleration is dv/dt =g-cv ,c=(6* pi * eta * r)/m.
# g=9.8, eta=10.5 ,r=0.0025 ,initial vel=0 , max time =0.005sec , number of time step= 25 , step size=0.0002, m=0.0005

# %%
import numpy as np
import matplotlib.pyplot as p
g=9.8
eta=10.5
r=0.0025
tmax=0.005
m=0.0005
tspt=25
tsize=0.0002
pi=3.14
v=(m*g)+20
V=[]
T=np.arange(0,0.005,0.0002)
for t in T:
  V.append(v)
  print("For time ",t,"\n","Velocity is", v)
  c=((6*pi*eta*r)/m)
  F=(m*g)-(m*c*v)
  A=g-(c*v)
  v=v+(A*tsize)
p.plot(T,V)
p.xlabel("Time (s)")
p.ylabel("Velocity (m/s)")
# Out:
# For time  0.0
#  Velocity is 20.0049
# For time  0.0002
#  Velocity is 16.049490682
# For time  0.0004
#  Velocity is 12.876540435286758
# For time  0.0006000000000000001
#  Velocity is 10.331263206378331
# For time  0.0008
#  Velocity is 8.28949271889257
# For time  0.001
#  Velocity is 6.651625269241242
# For time  0.0012000000000000001
#  Velocity is 5.33776075847994
# For time  0.0014
#  Velocity is 4.283804925237439
# For time  0.0016
#  Velocity is 3.4383426349269683
# For time  0.0018000000000000002
#  Velocity is 2.7601296948857157
# For time  0.002
#  Velocity is 2.2160808386434234
# For time  0.0022
#  Velocity is 1.7796557271429814
# For time  0.0024000000000000002
#  Velocity is 1.429564231199557
# For time  0.0026000000000000003
#  Velocity is 1.1487278349836605
# For time  0.0028
#  Velocity is 0.9234464946671928
# For time  0.003
#  Velocity is 0.7427303090921287
# For time  0.0032
#  Velocity is 0.5977633993475238
# For time  0.0034000000000000002
#  Velocity is 0.4814738436885966
# For time  0.0036000000000000003
#  Velocity is 0.3881886879301184
# For time  0.0038
#  Velocity is 0.3133572016837824
# For time  0.004
#  Velocity is 0.25332888004669657
# For time  0.004200000000000001
#  Velocity is 0.20517536099585906
# For time  0.0044
#  Velocity is 0.16654757108365822
# For time  0.0046
#  Velocity is 0.13556113057188895
# For time  0.0048000000000000004
#  Velocity is 0.11070442772215788
# Text(0, 0.5, 'Velocity (m/s)')
